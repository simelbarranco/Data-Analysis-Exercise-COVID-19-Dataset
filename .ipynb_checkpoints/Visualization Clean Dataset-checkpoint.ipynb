# %% [markdown]
# # Visualization of Trends and Patterns from Clean Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv("cleaned_dataset.csv")
data.head(-10)
# Out:
#                  Province/State  Country/Region      Lat     Long        Date  \
# 0             No Province/State     Afghanistan  33.9391  67.7100  2020-01-22
# 1             No Province/State         Albania  41.1533  20.1683  2020-01-22
# 2             No Province/State         Algeria  28.0339   1.6596  2020-01-22
# 3             No Province/State         Andorra  42.5063   1.5218  2020-01-22
# 4             No Province/State          Angola -11.2027  17.8739  2020-01-22
# ...                         ...             ...      ...      ...         ...
# 49053    British Virgin Islands  United Kingdom  18.4207 -64.6400  2020-07-27
# 49054  Turks and Caicos Islands  United Kingdom  21.6940 -71.7979  2020-07-27
# 49055         No Province/State        Botswana -22.3285  24.6849  2020-07-27
# 49056         No Province/State         Burundi  -3.3731  29.9189  2020-07-27
# 49057         No Province/State    Sierra Leone   8.4606 -11.7799  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 0              0       0          0       0  Eastern Mediterranean
# 1              0       0          0       0                 Europe
# 2              0       0          0       0                 Africa
# 3              0       0          0       0                 Europe
# 4              0       0          0       0                 Africa
# ...          ...     ...        ...     ...                    ...
# 49053          8       1          7       0                 Europe
# 49054         99       2         36      61                 Europe
# 49055        739       2         63     674                 Africa
# 49056        378       1        301      76                 Africa
# 49057       1783      66       1317     400                 Africa
#
# [49058 rows x 10 columns]
